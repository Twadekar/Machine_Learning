# %%
import matplotlib.pyplot as plt

# %%
kernals = ['RBF', 'Poly', 'Linear', 'Sigmoid']
accuracy = [68, 67, 61, 51]

# %%
plt.figure(figsize=(6, 4))
bars = plt.bar(kernals, accuracy, color=['green', 'blue', 'orange', 'red'])

# %% [markdown]
# Conclusion
# The SVM model was trained using 4 different kernals. The accuracy obtained were as follows:
# RBF -  68% (Highest accuracy)
# Polynominal - 67%
# Linear - 61%
# Sigmoid - 51%
#
#
# From these result, it's evident that RBF kernel have best performance and Polynominal is closed to it.
# Sigmoid kernel is worst
